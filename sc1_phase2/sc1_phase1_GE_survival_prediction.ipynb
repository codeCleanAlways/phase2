# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn

# %%
dfOutcomes = pd.read_csv("sc1_Phase1_GE_Outcome.tsv",sep="\t")
dfOutcomes['SURVIVAL_STATUS'].value_counts()
dfOutcomes[dfOutcomes['SURVIVAL_STATUS'] == 1].sample(n=51)
dfOutcomes.head()
# Out:
#      PATIENTID  SURVIVAL_STATUS
# 0  patient_290                1
# 1  patient_394                1
# 2   patient_81                1
# 3  patient_307                1
# 4   patient_14                1

# %%
dfPhenotypes = pd.read_csv("sc1_Phase1_GE_Phenotype.tsv",sep="\t")
dfPhenotypes = dfPhenotypes.replace(r'^\s*$', np.nan, regex=True)
dfPhenotypes = dfPhenotypes.replace(r'^IV', 4, regex=True)
dfPhenotypes = dfPhenotypes.replace(r'^III', 3, regex=True)
dfPhenotypes = dfPhenotypes.replace(r'^II', 2, regex=True)
dfPhenotypes = dfPhenotypes.replace(r'^I', 1, regex=True)
dfPhenotypes['WHO_GRADING'].replace(np.nan, 0, regex=True,inplace=True)
dfPhenotypes.head()
# Out:
#      PATIENTID  SEX RACE  WHO_GRADING   CANCER_TYPE
# 0  patient_290  NaN  NaN          2.0   ASTROCYTOMA
# 1  patient_394  NaN  NaN          0.0           GBM
# 2   patient_81  NaN  NaN          3.0   ASTROCYTOMA
# 3  patient_307  NaN  NaN          0.0  UNCLASSIFIED
# 4   patient_14  NaN  NaN          0.0           GBM

# %%
dfFeatures = pd.read_csv("sc1_Phase1_GE_FeatureMatrix.tsv",sep="\t")
dfFeatures.head()
# Out:
#      PATIENTID      A1BG  A1BG.AS1      A1CF        A2M   A2M.AS1     A2ML1  \
# 0  patient_290  6.557793  6.453623  5.302909  12.530607  6.082401  5.667769
# 1  patient_394  6.323015  6.305724  5.552097  13.000489  6.263721  5.347906
# 2   patient_81  6.669421  6.414214  5.478774  12.545510  5.940785  5.639510
# 3  patient_307  6.502573  6.508156  5.648495  12.407083  6.414991  5.493800
# 4   patient_14  6.624505  6.911232  5.614099  10.777103  6.236386  5.512900
#
#      A4GALT     A4GNT      AA06    ...       ZWILCH     ZWINT      ZXDA  \
# 0  6.764585  6.094459  6.240895    ...     7.338461  8.616562  6.587933
# 1  6.723860  6.143284  6.256355    ...     8.138918  9.463643  6.233711
# 2  6.752736  6.001829  6.148274    ...     7.754430  9.229166  6.288666
# 3  6.912802  6.072980  6.318908    ...     6.582457  8.851282  6.672033
# 4  7.178968  6.088447  6.091908    ...     7.176397  7.618780  6.086676
#
#        ZXDB      ZXDC    ZYG11A     ZYG11B        ZYX     ZZEF1      ZZZ3
# 0  6.034539  7.525232  5.847143   9.426022  10.027414  8.438376  8.853557
# 1  6.174691  8.169813  5.988549   9.988564  11.577409  8.672737  9.205295
# 2  5.957426  8.148327  6.190679   9.531540  11.180062  8.484453  8.856021
# 3  6.194203  7.576931  6.422759   9.057685  10.062035  8.508903  7.742661
# 4  6.096177  7.251395  6.090243  10.298209   9.443150  8.204315  8.606522
#
# [5 rows x 19336 columns]

# %%
dfs = pd.merge(dfPhenotypes,dfOutcomes,how="inner",on="PATIENTID")
dfMerged = pd.merge(dfs,dfFeatures,how="inner",on="PATIENTID")
dfMerged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 377 entries, 0 to 376
# Columns: 19341 entries, PATIENTID to ZZZ3
# dtypes: float64(19336), int64(1), object(4)
# memory usage: 55.6+ MB

# %%
#dfMerged = dfMerged[dfMerged.CANCER_TYPE != 'UNKNOWN']
#dfMerged = dfMerged[dfMerged.CANCER_TYPE != 'UNCLASSIFIED']
#dfMerged = dfMerged[dfMerged.CANCER_TYPE != 'MIXED']
#dfMerged = dfMerged[dfMerged.WHO_GRADING != 0]
dfCount = dfMerged[dfMerged['SURVIVAL_STATUS']==0]
dfCount.head()
# Out:
#       PATIENTID     SEX   RACE  WHO_GRADING  CANCER_TYPE  SURVIVAL_STATUS  \
# 37  patient_654    MALE  WHITE          4.0          GBM                0
# 39  patient_253    MALE  WHITE          0.0      UNKNOWN                0
# 43  patient_375  FEMALE  WHITE          4.0          GBM                0
# 47  patient_113  FEMALE  WHITE          2.0  ASTROCYTOMA                0
# 51  patient_468  FEMALE  WHITE          4.0          GBM                0
#
#         A1BG  A1BG.AS1      A1CF        A2M    ...       ZWILCH      ZWINT  \
# 37  6.888966  6.919759  5.382967  12.801268    ...     6.854620   7.365366
# 39  7.221225  6.741363  5.423092  10.374396    ...     8.550822  10.933867
# 43  6.791863  6.872367  5.427558  12.467948    ...     6.598569   8.258718
# 47  7.311807  7.044221  5.411064  13.161513    ...     7.288878   8.235849
# 51  6.743090  6.828674  5.518644  12.683945    ...     7.271699   7.938821
#
#         ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B        ZYX     ZZEF1  \
# 37  6.048575  5.966297  7.258182  6.013034  9.367449   9.538811  8.286802
# 39  6.294878  6.281912  7.849890  7.782124  8.459885   8.536307  8.456778
# 43  6.021195  5.960291  7.322752  6.385392  9.354172   9.746052  8.382402
# 47  6.376180  6.073544  7.275325  5.967357  9.289735  10.121427  8.246705
# 51  5.977331  5.937261  7.213713  6.109388  9.676957  10.017874  8.236059
#
#         ZZZ3
# 37  8.667675
# 39  9.196804
# 43  8.677187
# 47  8.874775
# 51  8.216178
#
# [5 rows x 19341 columns]

# %%
dfMergedDownSampledOutcomes=pd.concat([
        dfMerged[dfMerged['SURVIVAL_STATUS'] == 1].sample(n=len(dfCount.index)*6,replace=True),
        dfMerged[dfMerged['SURVIVAL_STATUS'] == 0].sample(n=len(dfCount.index)*5,replace=True)
])
dfMergedDownSampledOutcomes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 561 entries, 312 to 47
# Columns: 19341 entries, PATIENTID to ZZZ3
# dtypes: float64(19336), int64(1), object(4)
# memory usage: 82.8+ MB

# %%
from sklearn.feature_selection import GenericUnivariateSelect, chi2, SelectKBest, f_regression, RFE, mutual_info_classif
X = dfMergedDownSampledOutcomes
X = X.drop(columns=['PATIENTID','SEX','WHO_GRADING','RACE','CANCER_TYPE','SURVIVAL_STATUS'])
y = dfMergedDownSampledOutcomes.iloc[:,4]
y.value_counts()
# Out:
# GBM                  205
# ASTROCYTOMA          174
# UNKNOWN              120
# OLIGODENDROGLIOMA     55
# MIXED                  6
# UNCLASSIFIED           1
# Name: CANCER_TYPE, dtype: int64

# %%
bestfeatures = SelectKBest(score_func=chi2, k=500)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Genes','Score']  #naming the dataframe columns
#print(featureScores.nlargest(200,'Score'))  #print 10 best features

# %%
import matplotlib.pyplot as plt
Vals= featureScores.nlargest(200,'Score')  #print 10 best features
xVal = Vals['Genes']
yVal = Vals['Score']
plt.plot(xVal,yVal)  #print 10 best features
plt.show()

# %%
selCols = pd.Series(['SURVIVAL_STATUS'])
dfSelectedY = dfMergedDownSampledOutcomes.loc[:,selCols]
#xValDup = pd.Series(['CHI3L1','PTX3','COL3A1','IGFBP2','ADM','LTF','COL1A1'])
dfSelectedX = dfMergedDownSampledOutcomes.loc[:,xVal[0:]]
#print(dfSelectedX)

import seaborn as sns
corrMap = dfSelectedX.corr()
sns.heatmap(corrMap)

# %%
dfT = dfSelectedX
# Create correlation matrix
corr_matrix = dfT.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#print(upper)
# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.65)]
print(to_drop)
# Out:
# ['PTX3', 'IGFBP2', 'POSTN', 'EMP3', 'COL3A1', 'ADM', 'ETNPPL', 'TIMP1', 'MEOX2', 'COL1A1', 'ANXA1', 'LTF', 'SLC14A1', 'NNMT', 'CNTN3', 'LAMB1', 'MCUB', 'CTHRC1', 'PDPN', 'KLRC3', 'VEGFA', 'COL1A2', 'LOXL1', 'TNFAIP6', 'MOXD1', 'SH3GL2', 'CHI3L2', 'FCGBP', 'SCG3', 'LINC01088', 'IGF2BP3', 'KCND2', 'RBP1', 'TMEM100', 'LGALS3', 'COL4A2', 'COL6A3', 'SOD2', 'CHGB', 'BCAT1', 'LOX', 'LINC00844', 'SLC2A10', 'IGFBP3', 'FLJ16779', 'CFI', 'CSMD3', 'S100A8', 'TOX3', 'PHACTR3', 'COL5A2', 'B3GAT2', 'PLPPR1', 'FERMT1', 'COL4A1', 'PLA2G2A', 'RAB34', 'TMEM158', 'METTL7B', 'PLAT', 'RRM2', 'GALNT13', 'CD163', 'SNAP91', 'LUM', 'C1R', 'DIRAS3', 'SUSD5', 'SERPING1', 'CXCL8', 'PBK', 'MAOB', 'DPP10', 'UG0898H09', 'LIX1', 'GPNMB', 'DLL3', 'EYA1', 'SLC16A3', 'KCNN2', 'BMP2', 'MYL9', 'MGP', 'SYTL4', 'TOP2A', 'FUT9', 'FREM2', 'PHLDA2', 'GBP1', 'LOC389906', 'SMOC1', 'SELL', 'NSG2', 'DAAM2', 'SERPINA3', 'NOG', 'F3', 'OCIAD2', 'ESM1', 'SERPINE1', 'GPX8', 'PLIN2', 'TCIM', 'GDF15', 'GSAP', 'SHD', 'INA', 'NXPH1', 'ANXA2', 'GPR37', 'FAM155A', 'DCX', 'NRSN1', 'SPOCD1', 'RARRES2', 'SCN3B', 'NKAIN4', 'LINC01094', 'SNAI2', 'CSDC2', 'CNTN1', 'CLIC1', 'RASL10A', 'MOBP', 'LGALS1', 'TAGLN', 'NAMPT', 'SERPINH1', 'F13A1', 'PCSK2', 'ANGPT2', 'ACSL6', 'SCN3A', 'ZDHHC22', 'TGFBI', 'SRPX2', 'CA12', 'HES6', 'TSTD1', 'ALOX5AP', 'CENPK', 'IL17D', 'MARCH4', 'ENHO', 'SMIM3', 'PSRC1', 'CCL2', 'TUBB6', 'AEBP1', 'CBR1', 'FABP7', 'COL6A2', 'CA10', 'C1S', 'PLAU', 'NR2E1', 'CDCA7L', 'MAN1C1', 'SWAP70', 'AQP4', 'FZD6', 'FAM129A', 'PLP2', 'CAV1', 'SLITRK5', 'CA2', 'NRG3', 'FSTL5', 'ACTN1', 'NET1', 'ARSJ', 'ACSS3', 'RNASE4', 'CLEC5A', 'RAPGEF4', 'UNC80', 'TOM1L1', 'LY96', 'PHYHIPL', 'AQP1']

# %%
# Drop features 
dfT.drop(to_drop, axis=1,inplace=True)
corrMap = dfT.corr()
sns.heatmap(corrMap)
dfSelectedX = dfT

# %%
list(dfSelectedX)
# Out:
# ['CHI3L1',
#  'IL13RA2',
#  'AKR1C3',
#  'CHST9',
#  'GPR17',
#  'SFRP2',
#  'H19',
#  'P2RY12',
#  'CXCL14',
#  'KISS1R',
#  'ARHGAP36',
#  'ERMN',
#  'FREM3',
#  'MT1M',
#  'GFAP',
#  'INSM1',
#  'RYR3',
#  'ST6GAL2',
#  'ABI3BP',
#  'ADGRL2']

# %%
####SVM####
from sklearn import svm
from sklearn.model_selection import KFold,StratifiedKFold
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

clf = svm.SVC(kernel='rbf',gamma='auto',decision_function_shape='ovr')
cv = StratifiedKFold(n_splits=10, random_state=0, shuffle=True)

scaler = StandardScaler()

totScore=0
totSensitivity = 0
totSpecificity = 0
totAUC = 0
i=0
for train_index,test_index in cv.split(dfSelectedX,dfSelectedY):
    x_train, x_test = dfSelectedX.iloc[train_index], dfSelectedX.iloc[test_index]
    y_train, y_test = dfSelectedY.iloc[train_index], dfSelectedY.iloc[test_index]
    #print(x_train)
    #x_train = scaler.fit_transform(x_train)
    #x_test = scaler.fit_transform(x_test)
    
    #clf.fit(dfSelectedX, dfSelectedY.values.ravel())
    clf.fit(x_train, y_train.values.ravel())
    
    predictions = clf.predict(x_test)

    predY = pd.DataFrame(predictions,index= y_test.index, columns=['Predicted_type'])
    #print(predY)

    finalPred = pd.concat([y_test,predY],axis=1)
    #print(finalPred)
    print(multilabel_confusion_matrix(y_test, predictions))
    print("\n-----------------------------")
    tn,fp,fn,tp = confusion_matrix(y_test, predictions).ravel()
    print(" tn\tfp\tfn\t tp\n",tn,"\t",fp,"\t",fn,"\t",tp)
    score = clf.score(x_test, y_test)
    sensitivity = tp*100/(tp+fn)
    specificity = tn*100/(tn+fp)
    fpr, tpr, thresholds = metrics.roc_curve(y_test, predictions)
    auc = metrics.auc(fpr, tpr)
    print("\naccuracy:", score)
    print("sensitivity:", sensitivity)
    print("specificity:", specificity)
    print("AUC:", auc)
    print("-----------------------------\n")
    
    totScore = totScore + score
    totSensitivity = totSensitivity + sensitivity
    totSpecificity = totSpecificity + specificity
    totAUC = totAUC + auc
    i=i+1
    
print("average accuracy:", totScore/i)
print("average sensitivity:", totSensitivity/i)
print("average specificity:", totSpecificity/i)
print("average AUC:", totAUC/i)
# Out:
# [[[27  4]
#   [ 4 22]]
#
#  [[22  4]
#   [ 4 27]]]
#
# -----------------------------
#  tn	fp	fn	 tp
#  22 	 4 	 4 	 27
#
# accuracy: 0.8596491228070176
# sensitivity: 87.09677419354838
# specificity: 84.61538461538461
# AUC: 0.858560794044665
# -----------------------------
#
# [[[31  0]
#   [ 0 26]]
#
#  [[26  0]
#   [ 0 31]]]
#
# -----------------------------
#  tn	fp	fn	 tp
#  26 	 0 	 0 	 31
#
# accuracy: 1.0
# sensitivity: 100.0
# specificity: 100.0
# AUC: 1.0
# -----------------------------
#
# [[[31  0]
#   [ 0 26]]
#
#  [[26  0]
#   [ 0 31]]]
#
# -----------------------------
#  tn	fp	fn	 tp
#  26 	 0 	 0 	 31
#
# accuracy: 1.0
# sensitivity: 100.0
# specificity: 100.0
# AUC: 1.0
# -----------------------------
#
# [[[31  0]
#   [ 0 26]]
#
#  [[26  0]
#   [ 0 31]]]
#
# -----------------------------
#  tn	fp	fn	 tp
#  26 	 0 	 0 	 31
#
# accuracy: 1.0
# sensitivity: 100.0
# specificity: 100.0
# AUC: 1.0
# -----------------------------
#
# [[[30  1]
#   [ 2 24]]
#
#  [[24  2]
#   [ 1 30]]]
#
# -----------------------------
#  tn	fp	fn	 tp
#  24 	 2 	 1 	 30
#
# accuracy: 0.9473684210526315
# sensitivity: 96.7741935483871
# specificity: 92.3076923076923
# AUC: 0.9454094292803971
# -----------------------------
#
# [[[31  0]
#   [ 0 25]]
#
#  [[25  0]
#   [ 0 31]]]
#
# -----------------------------
#  tn	fp	fn	 tp
#  25 	 0 	 0 	 31
#
# accuracy: 1.0
# sensitivity: 100.0
# specificity: 100.0
# AUC: 1.0
# -----------------------------
#
# [[[29  1]
#   [ 1 24]]
#
#  [[24  1]
#   [ 1 29]]]
#
# -----------------------------
#  tn	fp	fn	 tp
#  24 	 1 	 1 	 29
#
# accuracy: 0.9636363636363636
# sensitivity: 96.66666666666667
# specificity: 96.0
# AUC: 0.9633333333333334
# -----------------------------
#
# [[[28  2]
#   [ 2 23]]
#
#  [[23  2]
#   [ 2 28]]]
#
# -----------------------------
#  tn	fp	fn	 tp
#  23 	 2 	 2 	 28
#
# accuracy: 0.9272727272727272
# sensitivity: 93.33333333333333
# specificity: 92.0
# AUC: 0.9266666666666667
# -----------------------------
#
# [[[28  2]
#   [ 1 24]]
#
#  [[24  1]
#   [ 2 28]]]
#
# -----------------------------
#  tn	fp	fn	 tp
#  24 	 1 	 2 	 28
#
# accuracy: 0.9454545454545454
# sensitivity: 93.33333333333333
# specificity: 96.0
# AUC: 0.9466666666666667
# -----------------------------
#
# [[[30  0]
#   [ 0 25]]
#
#  [[25  0]
#   [ 0 30]]]
#
# -----------------------------
#  tn	fp	fn	 tp
#  25 	 0 	 0 	 30
#
# accuracy: 1.0
# sensitivity: 100.0
# specificity: 100.0
# AUC: 1.0
# -----------------------------
#
# average accuracy: 0.9643381180223285
# average sensitivity: 96.72043010752688
# average specificity: 96.09230769230768
# average AUC: 0.9640636889991729
